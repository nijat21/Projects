# %%
import pandas as pd
import stastsmodels.api as sm
from statsmodels.datasets import cancer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/81804929/ch1.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bnijat21-code50-81804929-7vrgp766q29qv/workspaces/81804929/ch1.ipynb#ch0000000vscode-remote?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell://codespaces%2Bnijat21-code50-81804929-7vrgp766q29qv/workspaces/81804929/ch1.ipynb#ch0000000vscode-remote?line=1'>2</a> import stastsmodels.api as sm
#       <a href='vscode-notebook-cell://codespaces%2Bnijat21-code50-81804929-7vrgp766q29qv/workspaces/81804929/ch1.ipynb#ch0000000vscode-remote?line=2'>3</a> from statsmodels.datasets import cancer
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data = sm.datasets.get_rdataset('data', '/Users/nijatismayilov/Library/CloudStorage/OneDrive-KhazarUniversity/courses/BRM/Introduction\ to\ econometrics/lectures_dataset/wage1.RData')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspaces/81804929/ch1.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bnijat21-code50-81804929-7vrgp766q29qv/workspaces/81804929/ch1.ipynb#ch0000001vscode-remote?line=0'>1</a> data = sm.datasets.get_rdataset('data', '/Users/nijatismayilov/Library/CloudStorage/OneDrive-KhazarUniversity/courses/BRM/Introduction\ to\ econometrics/lectures_dataset/wage1.RData')
#
# NameError: name 'sm' is not defined
